# %% [markdown]
# # **ML Project: Tweet Sentiment Analysis**

# %% [markdown]
# **Workflow and Requirements for Submission of the Reference Model**
#
# This file contains all the workflow needed to arrive at the submission of our reference model that utilizes traditional supervised ML techniques (**SVM**, **Logistic Regression**).
#
# ---
#
# ### Required Files and Structure
#
# The following files are preliminary and **essential** to be in the **current folder** where this Jupyter Notebook is running:
#
# 1. **Dataset Folder**:
#    - The folder must be named **`twitter-datasets`**.
#    - It should contain the following files:
#      - **test_data.txt**: The test dataset.
#      - **train_neg.txt**: Negative training samples.
#      - **train_neg_full.txt**: Full negative training samples.
#      - **train_pos.txt**: Positive training samples.
#      - **train_pos_full.txt**: Full positive training samples.
#
# 2. **Vector Embeddings**:
#    - The file contains all the GloVe embeddings used throughout this process.
#    - It can be downloaded from the following link:
#      [https://nlp.stanford.edu/data/glove.twitter.27B.zip](https://nlp.stanford.edu/data/glove.twitter.27B.zip)
#
# 3. **SymSpell Dictionary**:
#    - The dictionary file used for spell checking is **`en-80k.txt`**.
#    - It can be downloaded from this link:
#      [https://github.com/wolfgarbe/SymSpell/blob/master/SymSpell.FrequencyDictionary/en-80k.txt](https://github.com/wolfgarbe/SymSpell/blob/master/SymSpell.FrequencyDictionary/en-80k.txt)
#
# 4. **Helpers File**:
#    - The file **`helpers.py`** must be included in the current directory.
#    - It contains utility functions used throughout the workflow, such as:
#      - Tokenization and preprocessing.
#      - Spell checking using SymSpell.
#      - Handling embeddings and batch processing.
#
# ---
#
# ### Important Notes:
# - The **names of the files should not be changed**.
# - To understand the reasoning behind certain parameters and thresholds used in this notebook, refer to the **`HP_Tuning.ipynb`** file, which should be available in this repository.
#
# ---

# %% [markdown]
# ### **Data Pre-processing**

# %% [markdown]
# **Import Libraries**

# %%
# Importing Libraries
import re
import random
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

# %%
# Importing NLTK resources for text preprocessing
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize stopwords
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/selim_sherif/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/selim_sherif/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/selim_sherif/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Importing Custom Helpers
import importlib
import helpers
from helpers import *
importlib.reload(helpers)
# Out:
# <module 'helpers' from '/home/selim_sherif/Documents/EPFL/MA1/CS-433_Machine-Learning/projects/project2/CS-433-ML-Project2/helpers.py'>

# %% [markdown]
# **Import Dataset**

# %%
pos_file = "twitter-datasets/train_pos_full.txt"
neg_file = "twitter-datasets/train_neg_full.txt"
test_file = "twitter-datasets/test_data.txt"
output_file = "vocab_tweets.txt"  # For cleaned tweets without labels

with open(pos_file, "r", encoding="utf-8") as pos_file:
    pos_tweets = pos_file.readlines()

with open(neg_file, "r", encoding="utf-8") as neg_file:
    neg_tweets= neg_file.readlines()

with open(test_file, "r", encoding="utf-8") as test_file:
    test_tweets= test_file.readlines()

print(f"Loaded {len(pos_tweets)} positive tweets.")
print(f"Loaded {len(neg_tweets)} negative tweets.")
print(f"Loaded {len(test_tweets)} negative tweets.")
# Out:
# Loaded 1250000 positive tweets.
# Loaded 1250000 negative tweets.
# Loaded 10000 negative tweets.

# %% [markdown]
# **Remove Duplicate and Empty Tweets**

# %%
# Clean tweets and process duplicates and empty tweets
pos_tweets = remove_duplicates_and_empty(pos_tweets)
neg_tweets = remove_duplicates_and_empty(neg_tweets)

# Get the lengths
length_pos = len(neg_tweets)
length_neg = len(neg_tweets)

# Output the lengths
print(f"Number of processed positive tweets: {length_pos}")
print(f"Number of processed negative tweets: {length_neg}")
# Out:
# Number of processed positive tweets: 1142838
# Number of processed negative tweets: 1142838

# %% [markdown]
# **Clean Useless Characters and Words**

# %%
c_pos_tweets = clean_tweets(pos_tweets)
c_neg_tweets = clean_tweets(neg_tweets)
c_test_tweets = clean_tweets(test_tweets)

# %% [markdown]
# **Fix Contraction, Tokenize and Spell Check the Tweets**
#
# The spell checker used here is **SymSpell**, which is robust but also very quick and efficient in this case with limited computational resources.

# %%
c2_pos_tweets = tokenize_and_correct_tweets(c_pos_tweets)
c2_neg_tweets = tokenize_and_correct_tweets(c_neg_tweets)
c2_test_tweets = tokenize_and_correct_tweets(c_test_tweets)

# %% [markdown]
# **Lemmatize the Tweets**
#
# The Lemmatizer used here is the classic `nltk` lemmatizer, which is good enough for this baseline model.

# %%
c3_pos_tweets = lemmatize_tweets(c2_pos_tweets)
c3_neg_tweets = lemmatize_tweets(c2_neg_tweets)
c3_test_tweets = lemmatize_tweets(c2_test_tweets)

# %% [markdown]
# **Merge the Tweets and Save the File (OPTIONAL to save file)**

# %%
# Combine the positive tweets with their labels (as tuples)
l_c3_pos_tweets = [(1, tweet) for tweet in c3_pos_tweets ]  # (label, tweet) for positive tweets
# Combine the negative tweets with their labels (as tuples)
l_c3_neg_tweets = [(0, tweet) for tweet in c3_neg_tweets ]  # (label, tweet) for negative tweets

# Combine and shuffle the data
all_tweets = c3_pos_tweets + c3_neg_tweets  # Only tweets (no labels)
l_all_tweets = l_c3_pos_tweets + l_c3_neg_tweets

# Shuffle the tweets
random.shuffle(all_tweets)
random.shuffle(l_all_tweets)

# %%
# Write only the tweets (without labels) to the output file
with open("all_tweets.txt", "w", encoding="utf-8") as f:
    for tweet in all_tweets:
        f.write(f"{tweet}\n")
# Shuffle the tweets


# Write only the tweets (without labels) to the output file
with open("l_all_tweets.txt", "w", encoding="utf-8") as f:
    for tweet in l_all_tweets:
        f.write(f"{tweet}\n")

# %% [markdown]
# #### **Build The Vocabulary .pkl Dict**

# %%
vocab_file = "vocab.pkl"               

print("Building vocabulary...")
vocab, word_counts = build_vocab(all_tweets)  # Get both vocab and frequencies
with open(vocab_file, "wb") as f:
    pickle.dump(vocab, f, protocol=pickle.HIGHEST_PROTOCOL)                  # Save the original vocab to the .pkl file

print(f"Vocabulary size: {len(vocab)}")
# Out:
# Building vocabulary...
# Vocabulary size: 5434

# %%
# Define the GloVe file and corresponding dimension
glove_file = "glove.twitter.27B.200d.txt"
embedding_dim = 200

# Process only the 200-dimensional GloVe embeddings
print(f"Processing GloVe embeddings for {embedding_dim} dimensions...")

# Load GloVe embeddings
glove_embeddings = load_glove_embeddings(glove_file)

# Map vocabulary to GloVe embeddings
embedding_matrix_200 = map_vocab_to_glove(vocab, glove_embeddings, embedding_dim)
print(f"Embedding matrix shape for {embedding_dim} dimensions: {embedding_matrix_200.shape}")

# Save embedding_matrix to file
output_embedding_file = f"embedding_matrix_glove_{embedding_dim}.npy"
np.save(output_embedding_file, embedding_matrix_200)
print(f"Saved embedding matrix to {output_embedding_file}")

print(f"Variable available for use: embedding_matrix_200")
# Out:
# Processing GloVe embeddings for 200 dimensions...
# Loaded 1193514 word vectors from GloVe.
# Embedding matrix shape for 200 dimensions: (26245, 200)
# Saved embedding matrix to embedding_matrix_glove_200.npy
# Variable available for use: embedding_matrix_200

# %% [markdown]
# ### **Make sure tweets tokens are part of the vocab**

# %%
print("Processing tweets...")
final_tweets = process_tweets(l_all_tweets, vocab )
print(f"Processed {len(final_tweets)} labeled tweets.")
# Out:
# Processing tweets...
# Skipping invalid tweet with label 1: ['tweetsformysweetbarbieforteza']
# Skipping invalid tweet with label 0: ['meany']
# Skipping invalid tweet with label 1: ['cheerleader', 'ifindthatattracrive']
# Skipping invalid tweet with label 1: ['jujurakusakithati']
# Skipping invalid tweet with label 1: ['messier']
# Skipping invalid tweet with label 1: ['thankyoou']
# Skipping invalid tweet with label 0: ['helpmeplease']
# Skipping invalid tweet with label 1: ['youknowyouliveinthesuburbswhenthatsthehighlightofyourday']
# Skipping invalid tweet with label 0: ['askplease']
# Skipping invalid tweet with label 1: ['goodmorningg']
# Skipping invalid tweet with label 0: ['rolando', 'bola', 'thaayzita']
# Skipping invalid tweet with label 1: ['followingback']
# Skipping invalid tweet with label 0: ['youonlytweetmewhenyourebored']
# Skipping invalid tweet with label 1: ['prick', 'youreallyareasessionpussy']
# Skipping invalid tweet with label 1: ['minister']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['iseewhatyoudidthere']
# Skipping invalid tweet with label 1: ['jedwardweloveyounomatterwhat']
# Skipping invalid tweet with label 0: ['mybestisnotgoodenough']
# Skipping invalid tweet with label 1: ['meredith']
# Skipping invalid tweet with label 1: ['golfing', 'misfit', 'endyourdaywithasmile']
# Skipping invalid tweet with label 1: ['retweetifyoucanreadthiswithnoproblemsasyouarejustthatsmart']
# Skipping invalid tweet with label 1: ['doomedfromthewomb']
# Skipping invalid tweet with label 1: ['yeahbuddy']
# Skipping invalid tweet with label 1: ['henley']
# Skipping invalid tweet with label 0: ['opium', 'theriyala']
# Skipping invalid tweet with label 1: ['demiisoureverything']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['somewhat']
# Skipping invalid tweet with label 1: ['haveagooddaytomorrow', 'goodnightworld']
# Skipping invalid tweet with label 1: ['supershoutout_special']
# Skipping invalid tweet with label 0: ['contestant']
# Skipping invalid tweet with label 0: ['imissthatmomentsomuch']
# Skipping invalid tweet with label 1: ['thatswhatsup']
# Skipping invalid tweet with label 1: ['laughattakfornoreason']
# Skipping invalid tweet with label 1: ['whey']
# Skipping invalid tweet with label 1: ['baltimore']
# Skipping invalid tweet with label 1: ['pf', 'pleaselaugh']
# Skipping invalid tweet with label 0: ['toomuchresponsibility', 'hategrowingup']
# Skipping invalid tweet with label 1: ['yourunenough', 'dontfretpet']
# Skipping invalid tweet with label 0: ['fckkgnbgtguasmlo']
# Skipping invalid tweet with label 1: ['aegis']
# Skipping invalid tweet with label 1: ['thankyouthankyouthankyou']
# Skipping invalid tweet with label 1: ['thankyouu', 'krishna']
# Skipping invalid tweet with label 1: ['somewhat']
# Skipping invalid tweet with label 1: ['awesomeness']
# Skipping invalid tweet with label 1: ['hanky']
# Skipping invalid tweet with label 0: ['bugger']
# Skipping invalid tweet with label 1: ['contour']
# Skipping invalid tweet with label 1: ['queremostwitcamsomic', 'queremostwitcamsomic', 'queremostwitcamsomic', 'queremostwitcamsomic']
# Skipping invalid tweet with label 1: ['aright']
# Skipping invalid tweet with label 0: ['manor', 'abbe']
# Skipping invalid tweet with label 1: ['hotly']
# Skipping invalid tweet with label 1: ['pleasefollowback']
# Skipping invalid tweet with label 1: ['henley']
# Skipping invalid tweet with label 1: ['thankyouu', 'mimic']
# Skipping invalid tweet with label 1: ['whateverydirectionerneedstoknow', 'trance']
# Skipping invalid tweet with label 0: ['whereareyou']
# Skipping invalid tweet with label 0: ['withoutglee']
# Skipping invalid tweet with label 1: ['takeaseatwherecanitakeaseatonmybedpleaseidonthaveachairinmyroombutidohavealittlestoolactually']
# Skipping invalid tweet with label 1: ['iknowsomeone']
# Skipping invalid tweet with label 1: ['mygirlfriendsaidshehateswhenpeoplemaketheirhashtagstoolongoppssorryasiaireallyhopethisisnttoolongifitistoolongpleaseforgivemelolimdone']
# Skipping invalid tweet with label 0: ['ilovethatmovie']
# Skipping invalid tweet with label 0: ['emotionally', 'tortured']
# Skipping invalid tweet with label 0: ['idaho']
# Skipping invalid tweet with label 1: ['tweetagainzacefron', 'zattackerswantlivechat', 'zacdoatwitcam']
# Skipping invalid tweet with label 1: ['whassup']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['jolly', 'rancher', 'thankscoachbenway']
# Skipping invalid tweet with label 1: ['followfriday']
# Skipping invalid tweet with label 1: ['thadtyha', 'thibphanny']
# Skipping invalid tweet with label 1: ['teamkelly']
# Skipping invalid tweet with label 1: ['vipnotts']
# Skipping invalid tweet with label 1: ['thanksyou']
# Skipping invalid tweet with label 0: ['solely']
# Skipping invalid tweet with label 1: ['teamcagle']
# Skipping invalid tweet with label 1: ['theslothturnstomorrow']
# Skipping invalid tweet with label 1: ['smartgirl']
# Skipping invalid tweet with label 1: ['che', 'giornatina']
# Skipping invalid tweet with label 1: ['fleck']
# Skipping invalid tweet with label 1: ['jordananderic', 'jordananderic', 'jordananderic', 'jordananderic', 'jordananderic', 'jordananderic', 'jordananderic', 'jordananderic', 'jordananderic']
# Skipping invalid tweet with label 1: ['thankyouu', 'amino']
# Skipping invalid tweet with label 1: ['thebigbangtheory']
# Skipping invalid tweet with label 1: ['nee', 'streetdance']
# Skipping invalid tweet with label 1: ['thefairytopia']
# Skipping invalid tweet with label 0: ['oneerlyk']
# Skipping invalid tweet with label 0: ['anthem', 'anthem']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['baleskeplease']
# Skipping invalid tweet with label 0: ['emotionally', 'drained']
# Skipping invalid tweet with label 1: ['specifically', 'ore']
# Skipping invalid tweet with label 1: ['lilly']
# Skipping invalid tweet with label 1: ['hahahhaa']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['olga']
# Skipping invalid tweet with label 1: ['sayingnothing']
# Skipping invalid tweet with label 1: ['thankyouplease']
# Skipping invalid tweet with label 1: ['thatswhatfriendsarefor']
# Skipping invalid tweet with label 1: ['bonertown']
# Skipping invalid tweet with label 1: ['hotvoteboost', 'chasingthesun']
# Skipping invalid tweet with label 1: ['gafertnoon']
# Skipping invalid tweet with label 1: ['whey']
# Skipping invalid tweet with label 1: ['contour', 'mister']
# Skipping invalid tweet with label 1: ['thisishowwedoit']
# Skipping invalid tweet with label 1: ['lully', 'bubbly']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 0: ['thatshouldbemejustin']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['howimetyourmother']
# Skipping invalid tweet with label 1: ['lilly']
# Skipping invalid tweet with label 1: ['shelly']
# Skipping invalid tweet with label 0: ['soundslikeimissedoutbigtime']
# Skipping invalid tweet with label 1: ['unwelcome', 'thar']
# Skipping invalid tweet with label 1: ['thankyoulordforanotherday']
# Skipping invalid tweet with label 0: ['dunnowhereuare']
# Skipping invalid tweet with label 1: ['heyheyheyhey']
# Skipping invalid tweet with label 0: ['whirlwhirlwhirlwhirl']
# Skipping invalid tweet with label 0: ['awwthatscute', 'iwasjokingyoutit', 'yeahitsforbrainypeople']
# Skipping invalid tweet with label 1: ['basswood']
# Skipping invalid tweet with label 1: ['abovetheinfluence']
# Skipping invalid tweet with label 1: ['responded']
# Skipping invalid tweet with label 0: ['peppleasestay']
# Skipping invalid tweet with label 1: ['nowfollowing']
# Skipping invalid tweet with label 0: ['thingsthatannoyme', 'heartburn']
# Skipping invalid tweet with label 1: ['pollack']
# Skipping invalid tweet with label 1: ['thnxx']
# Skipping invalid tweet with label 0: ['siam']
# Skipping invalid tweet with label 1: ['cert']
# Skipping invalid tweet with label 1: ['thewantedonthevoice', 'happybirthdatynathan']
# Skipping invalid tweet with label 0: ['pleasestopfighting']
# Skipping invalid tweet with label 1: ['endyourdaywithasmile']
# Skipping invalid tweet with label 1: ['chasingthesun']
# Skipping invalid tweet with label 0: ['ificouldiwould']
# Skipping invalid tweet with label 1: ['swine']
# Skipping invalid tweet with label 1: ['sorrel']
# Skipping invalid tweet with label 0: ['icntlifewithoutyou']
# Skipping invalid tweet with label 1: ['nothongthursday']
# Skipping invalid tweet with label 1: ['followmeplease']
# Skipping invalid tweet with label 1: ['actingtheladontwitter', 'backup']
# Skipping invalid tweet with label 1: ['happybirthday']
# Skipping invalid tweet with label 1: ['whaticanseerightnow']
# Skipping invalid tweet with label 0: ['withoutcomments']
# Skipping invalid tweet with label 1: ['theslothturnstomorrow', 'theslothturnstomorrow', 'theslothturnstomorrow']
# Skipping invalid tweet with label 1: ['whaticanseerightnow']
# Skipping invalid tweet with label 1: ['thankyouu', 'mba']
# Skipping invalid tweet with label 0: ['imissyoumissyoumissyoumissyoureallyreallymissyouimissyousobadlyofficiallymissingyounald']
# Skipping invalid tweet with label 1: ['missyouto', 'youaremyamigo', 'ilearnedthatinspanish']
# Skipping invalid tweet with label 1: ['imgonnaneedthat']
# Skipping invalid tweet with label 1: ['holawas', 'midwinter']
# Skipping invalid tweet with label 1: ['henley']
# Skipping invalid tweet with label 1: ['fuckthatfatbitch', 'burgh', 'vile', 'iwannabesickinherface']
# Skipping invalid tweet with label 1: ['peopleiwillneverregretknowingthem']
# Skipping invalid tweet with label 0: ['pubis']
# Skipping invalid tweet with label 1: ['yeaboi']
# Skipping invalid tweet with label 1: ['playingwithfireagain']
# Skipping invalid tweet with label 1: ['whop', 'whop']
# Skipping invalid tweet with label 0: ['mahatma']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['givedatimewiththeirfamily', 'givedatimewiththeirfamily', 'givedatimewiththeirfamily']
# Skipping invalid tweet with label 1: ['beentheredonethat']
# Skipping invalid tweet with label 0: ['heythatsnotnicejoe']
# Skipping invalid tweet with label 1: ['blessedtohaveyouasafather']
# Skipping invalid tweet with label 0: ['twitteame']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['happythoughts']
# Skipping invalid tweet with label 1: ['thnakyou']
# Skipping invalid tweet with label 0: ['nee']
# Skipping invalid tweet with label 1: ['sally']
# Skipping invalid tweet with label 1: ['haveanicelythbirthdaynathan']
# Skipping invalid tweet with label 1: ['majorloveforthat']
# Skipping invalid tweet with label 0: ['iwishicould']
# Skipping invalid tweet with label 1: ['hithinhas']
# Skipping invalid tweet with label 1: ['mentally', 'elevated']
# Skipping invalid tweet with label 0: ['mentiroso', 'omen']
# Skipping invalid tweet with label 0: ['zaynpleasestopsmoking']
# Skipping invalid tweet with label 1: ['justasneakydouble', 'thatisall']
# Skipping invalid tweet with label 1: ['incroyable', 'endyourdaywithasmile']
# Skipping invalid tweet with label 1: ['africandad', 'wordsafricanscreated', 'terra']
# Skipping invalid tweet with label 0: ['teamed']
# Skipping invalid tweet with label 1: ['chasingthesun', 'thewantedepdays']
# Skipping invalid tweet with label 0: ['thankyouu']
# Skipping invalid tweet with label 0: ['valeria']
# Skipping invalid tweet with label 1: ['boogie']
# Skipping invalid tweet with label 1: ['onlypeoplethatfollowusbothcanseeanywaysoweregood']
# Skipping invalid tweet with label 1: ['hanky']
# Skipping invalid tweet with label 1: ['thankyouu', 'patel']
# Skipping invalid tweet with label 0: ['monthswithoutamy']
# Skipping invalid tweet with label 1: ['kayaking', 'lovingthisweather']
# Skipping invalid tweet with label 1: ['liamandniallaresexyandtheyknowit']
# Skipping invalid tweet with label 0: ['coherence']
# Skipping invalid tweet with label 0: ['officiallylatetwenties']
# Skipping invalid tweet with label 0: ['firmly']
# Skipping invalid tweet with label 0: ['signsthatyouugly']
# Skipping invalid tweet with label 1: ['kendallpleasesayyes']
# Skipping invalid tweet with label 0: ['ajajaja']
# Skipping invalid tweet with label 1: ['whaticanseerightnow']
# Skipping invalid tweet with label 1: ['sigma']
# Skipping invalid tweet with label 1: ['sobersally']
# Skipping invalid tweet with label 1: ['potbelly']
# Skipping invalid tweet with label 1: ['queensland']
# Skipping invalid tweet with label 1: ['willy']
# Skipping invalid tweet with label 1: ['knowitall']
# Skipping invalid tweet with label 1: ['pleaseperish', 'insidejoke']
# Skipping invalid tweet with label 0: ['nearlyfriday', 'nearlyhometime', 'cantbebothered', 'pharmacy', 'oneofthosedays']
# Skipping invalid tweet with label 0: ['feelingrough']
# Skipping invalid tweet with label 1: ['haveanicelythbabynath']
# Skipping invalid tweet with label 1: ['moswantedcrew', 'moswantedcrew', 'moswantedcrew', 'moswantedcrew', 'moswantedcrew', 'moswantedcrew', 'moswantedcrew', 'moswantedcrew']
# Skipping invalid tweet with label 0: ['djdbdhsibd']
# Skipping invalid tweet with label 0: ['wheheheheh']
# Skipping invalid tweet with label 0: ['yaw']
# Skipping invalid tweet with label 1: ['thewantedepdays']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['ohyesquitepartialtotheoddvodkamyselfnicewithtonicandasliceoflime']
# Skipping invalid tweet with label 1: ['felix', 'pasco']
# Skipping invalid tweet with label 1: ['forealdoe']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['tania']
# Skipping invalid tweet with label 1: ['goodburger']
# Skipping invalid tweet with label 1: ['pander', 'thudangi']
# Skipping invalid tweet with label 1: ['potheadproblems']
# Skipping invalid tweet with label 1: ['lyricalgenious', 'dontstoptilyagetenough']
# Skipping invalid tweet with label 1: ['nonsense']
# Skipping invalid tweet with label 1: ['wassupp']
# Skipping invalid tweet with label 1: ['ifyouthinkimabitchyoushouldmeetmyaunt']
# Skipping invalid tweet with label 0: ['sigueme']
# Skipping invalid tweet with label 1: ['thoughtsduringschoollunch']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['bienhechismo']
# Skipping invalid tweet with label 1: ['lookformewhenifeelgood']
# Skipping invalid tweet with label 1: ['whatareyousaying']
# Skipping invalid tweet with label 1: ['okedokie']
# Skipping invalid tweet with label 1: ['ogre']
# Skipping invalid tweet with label 1: ['saythat']
# Skipping invalid tweet with label 1: ['witty', 'bitty', 'piggy', 'oscarmeyerbaccon', 'gotothemarket']
# Skipping invalid tweet with label 1: ['thankyouh']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['thankyoouu']
# Skipping invalid tweet with label 0: ['thatawkwardmomentwhenyoupromiseusakoganvideoandwestilldonthaveit']
# Skipping invalid tweet with label 0: ['thingsilookfor', 'flurry']
# Skipping invalid tweet with label 0: ['defame']
# Skipping invalid tweet with label 1: ['butreally']
# Skipping invalid tweet with label 1: ['wewouldknow']
# Skipping invalid tweet with label 0: ['adelaideshouldbeclosertomelbounre']
# Skipping invalid tweet with label 1: ['tier']
# Skipping invalid tweet with label 1: ['replacegleesongswithfaberry', 'replacegleesongswithfaberry']
# Skipping invalid tweet with label 1: ['thoughsduringschool']
# Skipping invalid tweet with label 0: ['byebilly']
# Skipping invalid tweet with label 1: ['jataka']
# Skipping invalid tweet with label 0: ['justinshoulddoxaswaghjklx']
# Skipping invalid tweet with label 1: ['friendsday']
# Skipping invalid tweet with label 1: ['grease']
# Skipping invalid tweet with label 0: ['hickman']
# Skipping invalid tweet with label 1: ['pfaplayeroftheyear', 'gareth', 'bale']
# Skipping invalid tweet with label 0: ['shush']
# Skipping invalid tweet with label 1: ['grease', 'snowshoeing']
# Skipping invalid tweet with label 1: ['twitterduringthedarkcuz_twitterafterdark_istechnicallymorning']
# Skipping invalid tweet with label 1: ['achoo']
# Skipping invalid tweet with label 1: ['takeabrolly']
# Skipping invalid tweet with label 1: ['ubersocial']
# Skipping invalid tweet with label 1: ['displease']
# Skipping invalid tweet with label 1: ['rollsomething']
# Skipping invalid tweet with label 1: ['followbck']
# Skipping invalid tweet with label 1: ['thankyouu', 'sunni']
# Skipping invalid tweet with label 1: ['thankkyas']
# Skipping invalid tweet with label 1: ['kendallpleasesayyes', 'kendallmightsayyes', 'kendallsayyes']
# Skipping invalid tweet with label 1: ['phat', 'phat', 'phat', 'patty', 'phat']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['enakku', 'kavithai', 'lama', 'sulla', 'theriyaadhu']
# Skipping invalid tweet with label 1: ['popoutanother']
# Skipping invalid tweet with label 1: ['yeahokay']
# Skipping invalid tweet with label 0: ['toothache', 'waldo']
# Skipping invalid tweet with label 0: ['hanky']
# Skipping invalid tweet with label 1: ['whohoho']
# Skipping invalid tweet with label 1: ['teamluv']
# Skipping invalid tweet with label 0: ['somanybffs', 'igetconfused']
# Skipping invalid tweet with label 1: ['thankyaa']
# Skipping invalid tweet with label 1: ['niallwithkoala']
# Skipping invalid tweet with label 1: ['whenwhenwhenwhen']
# Skipping invalid tweet with label 0: ['stoppostingpictureswiththatdeliciouscupcakeoriwilbiteyoubecauseitlookssoawesomeandiwanttoeatit']
# Skipping invalid tweet with label 1: ['randomfactsfromalegra']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['grave']
# Skipping invalid tweet with label 1: ['cheerfully']
# Skipping invalid tweet with label 1: ['dilly']
# Skipping invalid tweet with label 0: ['unloved']
# Skipping invalid tweet with label 1: ['thugshiit', 'thesemotherfuckersgonelearntoday']
# Skipping invalid tweet with label 1: ['thankyouu']
# Skipping invalid tweet with label 1: ['thankkyouu']
# Skipping invalid tweet with label 0: ['golly']
# Skipping invalid tweet with label 0: ['sickness']
# Skipping invalid tweet with label 0: ['meany']
# Skipping invalid tweet with label 1: ['heyheyhey']
# Skipping invalid tweet with label 1: ['whats']
# Skipping invalid tweet with label 1: ['iyar', 'sahara']
# Skipping invalid tweet with label 1: ['liampleasefollowme']
# Skipping invalid tweet with label 1: ['dshouldfollowdirectionersindonesia']
# Skipping invalid tweet with label 1: ['thankkyou']
# Skipping invalid tweet with label 0: ['whee']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['supershoutout_vips_stars']
# Skipping invalid tweet with label 1: ['wehavenothingwithoutchriscolfer']
# Skipping invalid tweet with label 1: ['thingsidobest']
# Skipping invalid tweet with label 1: ['whathappen']
# Skipping invalid tweet with label 1: ['thankkya']
# Skipping invalid tweet with label 1: ['youaremyfavoritepersonontwitter']
# Skipping invalid tweet with label 1: ['secondhand', 'serenade', 'throwback']
# Skipping invalid tweet with label 1: ['yeayeayea']
# Skipping invalid tweet with label 1: ['bestsmiles']
# Skipping invalid tweet with label 1: ['youknowyoureacheerleaderwhen']
# Skipping invalid tweet with label 1: ['bsbthanniversary']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['hahahhaaha', 'yousuck', 'youdidthatatvolleyball']
# Skipping invalid tweet with label 1: ['startyourdaywithasmile']
# Skipping invalid tweet with label 0: ['imissmyparents', 'whycouldntyoustaytogether']
# Skipping invalid tweet with label 1: ['displease']
# Skipping invalid tweet with label 1: ['consistently', 'unpredictable']
# Skipping invalid tweet with label 0: ['tenangingueplease']
# Skipping invalid tweet with label 1: ['nowfollowing']
# Skipping invalid tweet with label 1: ['voila']
# Skipping invalid tweet with label 0: ['adaywithoutuislikeayearwithoutrain', 'kazan']
# Skipping invalid tweet with label 0: ['smelly', 'pigeon']
# Skipping invalid tweet with label 1: ['thewianggia', 'makasih', 'sank']
# Skipping invalid tweet with label 0: ['thingsinmylifethatarepriceless']
# Skipping invalid tweet with label 1: ['darethebestgroupintheworld']
# Skipping invalid tweet with label 1: ['bitchplease']
# Skipping invalid tweet with label 1: ['evidently']
# Skipping invalid tweet with label 1: ['directionersneedanothertwitcam']
# Skipping invalid tweet with label 1: ['thankless']
# Skipping invalid tweet with label 0: ['pleasecomeherelookmyconditionnow']
# Skipping invalid tweet with label 1: ['livethewish', 'humanfamily', 'loverevolution']
# Skipping invalid tweet with label 1: ['touche']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['elvis', 'hammond']
# Skipping invalid tweet with label 1: ['offcourse']
# Skipping invalid tweet with label 1: ['directioneraresexymotherfuckers', 'directionersarededicatedfansandsexypotatoeswholoveonedirectionsomuchwewoulddieforthem']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['tangirlprobs']
# Skipping invalid tweet with label 1: ['everythingaboutd']
# Skipping invalid tweet with label 1: ['salem']
# Skipping invalid tweet with label 1: ['spamfalmpacehashtaglusheverythingbasically']
# Skipping invalid tweet with label 0: ['thatawkwardmomentwhenaugieinternettakesaneternitytoloadthevideo']
# Skipping invalid tweet with label 0: ['washout']
# Skipping invalid tweet with label 1: ['rainwithbenefits']
# Skipping invalid tweet with label 1: ['yayaayay', 'thankyoy']
# Skipping invalid tweet with label 1: ['whey']
# Skipping invalid tweet with label 0: ['whats']
# Skipping invalid tweet with label 1: ['nowfollowingback']
# Skipping invalid tweet with label 1: ['whaddup', 'thickness']
# Skipping invalid tweet with label 1: ['ballad']
# Skipping invalid tweet with label 1: ['whey', 'bitchy']
# Skipping invalid tweet with label 1: ['justafloridathing', 'gladyouunderstand']
# Skipping invalid tweet with label 1: ['idontsmokethough']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['godmorning']
# Skipping invalid tweet with label 0: ['humph']
# Skipping invalid tweet with label 1: ['bm', 'bm', 'bm']
# Skipping invalid tweet with label 0: ['indonesianenchancersfeelsorry']
# Skipping invalid tweet with label 1: ['flashback', 'tittytuesday', 'twitterafterdark']
# Skipping invalid tweet with label 1: ['teamthickness']
# Skipping invalid tweet with label 1: ['teamblekboys', 'strictly']
# Skipping invalid tweet with label 0: ['teamtaktengoklagibattleshipthehugergamestreetdancetitanic']
# Skipping invalid tweet with label 1: ['purpleleopardmudcake']
# Skipping invalid tweet with label 1: ['strasbourg']
# Skipping invalid tweet with label 1: ['citylightztosupportolly']
# Skipping invalid tweet with label 0: ['godpleasehelpme']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['mythoughtsduringschool']
# Skipping invalid tweet with label 1: ['sweetlifemolly']
# Skipping invalid tweet with label 1: ['crabby', 'patty']
# Skipping invalid tweet with label 1: ['replacegleesongswithfaberry', 'uptown', 'ferry']
# Skipping invalid tweet with label 1: ['thanksthanks']
# Skipping invalid tweet with label 1: ['fabfridayfollow']
# Skipping invalid tweet with label 1: ['thingsthatmakemehappy']
# Skipping invalid tweet with label 1: ['thingsthatmakemesmile']
# Skipping invalid tweet with label 0: ['ayudame']
# Skipping invalid tweet with label 1: ['thisiswhyimstillanangel']
# Skipping invalid tweet with label 0: ['nosy', 'anally']
# Skipping invalid tweet with label 0: ['hugmeplease']
# Skipping invalid tweet with label 1: ['chasingthesun', 'thewantedepdays']
# Skipping invalid tweet with label 1: ['taylorpleasedoatwitcam', 'taylorpleasedoatwitcam', 'taylorpleasedoatwitcam', 'taylorpleasedoatwitcam', 'taylorpleasedoatwitcam']
# Skipping invalid tweet with label 1: ['iamheretoentertain', 'iwishiwastheretoo', 'exceptthatitsyouranniversary']
# Skipping invalid tweet with label 1: ['lifeisrough', 'butfuckyou']
# Skipping invalid tweet with label 1: ['followingback']
# Skipping invalid tweet with label 1: ['africandad', 'wordsafricanscreated', 'terra']
# Skipping invalid tweet with label 1: ['hamburger', 'helper', 'displease']
# Skipping invalid tweet with label 0: ['imissyoumorethananythingfadlyfathurrahman']
# Skipping invalid tweet with label 1: ['chasingthesun', 'thewantedepdays']
# Skipping invalid tweet with label 0: ['somebodykillmeplease']
# Skipping invalid tweet with label 1: ['kendallpleasesayyes']
# Skipping invalid tweet with label 0: ['willy', 'willy', 'willy', 'willy']
# Skipping invalid tweet with label 1: ['nowfollowing']
# Skipping invalid tweet with label 0: ['oslo']
# Skipping invalid tweet with label 1: ['youknowhowthatgo']
# Skipping invalid tweet with label 1: ['copitlikeasheepdoesfromyou']
# Skipping invalid tweet with label 1: ['podstawowy', 'angielski']
# Skipping invalid tweet with label 1: ['immensely']
# Skipping invalid tweet with label 1: ['smelly']
# Skipping invalid tweet with label 1: ['wonderfully', 'succinct']
# Skipping invalid tweet with label 1: ['takealook']
# Skipping invalid tweet with label 1: ['replacedsongswithcarrots']
# Skipping invalid tweet with label 1: ['lovethispicture']
# Skipping invalid tweet with label 1: ['goodlooks']
# Skipping invalid tweet with label 0: ['jajajaja', 'comprendeme']
# Skipping invalid tweet with label 0: ['gash', 'thatisall']
# Skipping invalid tweet with label 1: ['alma', 'lng']
# Skipping invalid tweet with label 1: ['pow', 'pow']
# Skipping invalid tweet with label 1: ['happybirthdaynathanthesloth']
# Skipping invalid tweet with label 1: ['thnxx']
# Skipping invalid tweet with label 1: ['genial', 'niche', 'gupta']
# Skipping invalid tweet with label 0: ['eager']
# Skipping invalid tweet with label 0: ['withdraw']
# Skipping invalid tweet with label 1: ['wheresmephone', 'wheresmekeys']
# Skipping invalid tweet with label 1: ['somethingboutatruckk']
# Skipping invalid tweet with label 1: ['whop']
# Skipping invalid tweet with label 0: ['notplayingthedevils', 'onlyworksagainstthedevils']
# Skipping invalid tweet with label 1: ['thankless']
# Skipping invalid tweet with label 1: ['precise']
# Skipping invalid tweet with label 1: ['thaistephanie']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['thegirlverse']
# Skipping invalid tweet with label 1: ['capitol']
# Skipping invalid tweet with label 0: ['sabina', 'almskeenaelly', 'btdawm']
# Skipping invalid tweet with label 1: ['pleaseandthankyou']
# Skipping invalid tweet with label 1: ['groove']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['myangelwithoutwings']
# Skipping invalid tweet with label 1: ['happybirthdaynathan']
# Skipping invalid tweet with label 1: ['soyouknowitsreal']
# Skipping invalid tweet with label 1: ['boa', 'noisy', 'gated']
# Skipping invalid tweet with label 1: ['obviate']
# Skipping invalid tweet with label 1: ['thankyouu']
# Skipping invalid tweet with label 0: ['whensongsshowhowyoufeel']
# Skipping invalid tweet with label 1: ['duly', 'noted']
# Skipping invalid tweet with label 0: ['pobretica']
# Skipping invalid tweet with label 1: ['stflywithba']
# Skipping invalid tweet with label 1: ['jolly', 'rancher']
# Skipping invalid tweet with label 1: ['somethingmomsneversay']
# Skipping invalid tweet with label 1: ['usaf', 'sulla']
# Skipping invalid tweet with label 0: ['jajajaja', 'collate', 'vicki']
# Skipping invalid tweet with label 1: ['lolololol', 'truthandhumility']
# Skipping invalid tweet with label 0: ['chilly']
# Skipping invalid tweet with label 1: ['whats']
# Skipping invalid tweet with label 1: ['itsthebabysbirthday']
# Skipping invalid tweet with label 1: ['followfriday']
# Skipping invalid tweet with label 1: ['wassgoody']
# Skipping invalid tweet with label 0: ['pleasedontletmebeill']
# Skipping invalid tweet with label 1: ['whop']
# Skipping invalid tweet with label 1: ['iloveyoutoobaee']
# Skipping invalid tweet with label 1: ['whinge', 'whinge', 'whinge']
# Skipping invalid tweet with label 1: ['thankyouu']
# Skipping invalid tweet with label 0: ['walkedrightintothatone']
# Skipping invalid tweet with label 1: ['vertically', 'challenged']
# Skipping invalid tweet with label 1: ['whichever']
# Skipping invalid tweet with label 1: ['khalaeliahsparty']
# Skipping invalid tweet with label 0: ['questionsthatdontgetanswers']
# Skipping invalid tweet with label 1: ['holler', 'noonesaysthat']
# Skipping invalid tweet with label 0: ['pitt']
# Skipping invalid tweet with label 0: ['whatdidido', 'ithoughtwewerefriends']
# Skipping invalid tweet with label 0: ['thalia']
# Skipping invalid tweet with label 1: ['whoso']
# Skipping invalid tweet with label 0: ['killingmesoftly']
# Skipping invalid tweet with label 1: ['startyourdaywithasmile']
# Skipping invalid tweet with label 1: ['chilly']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['whuzzup']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['greenhouse']
# Skipping invalid tweet with label 0: ['wewillalwaysloveyougreyson', 'takealookatgreysonnow', 'greysonfansdayshouldbefree']
# Skipping invalid tweet with label 1: ['metalshoutouts']
# Skipping invalid tweet with label 1: ['drawsomething']
# Skipping invalid tweet with label 0: ['noun']
# Skipping invalid tweet with label 1: ['manythanks']
# Skipping invalid tweet with label 1: ['keystothecity']
# Skipping invalid tweet with label 0: ['thatwasjustrude']
# Skipping invalid tweet with label 1: ['favoritetweetstoread']
# Skipping invalid tweet with label 1: ['theressomethinginthewater']
# Skipping invalid tweet with label 1: ['lightly', 'tanned']
# Skipping invalid tweet with label 1: ['getwellreallysoon']
# Skipping invalid tweet with label 1: ['hilariousthatyouhashtageverything']
# Skipping invalid tweet with label 0: ['canteen']
# Skipping invalid tweet with label 0: ['chilly']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 0: ['boasted']
# Skipping invalid tweet with label 1: ['illgetitwithyou']
# Skipping invalid tweet with label 1: ['naughtygirl']
# Skipping invalid tweet with label 1: ['imperfectly', 'imperfect']
# Skipping invalid tweet with label 0: ['thisntwitcamisthebestthingever']
# Skipping invalid tweet with label 1: ['thoughduringschool', 'lalalalalalalala']
# Skipping invalid tweet with label 1: ['liamdoatwitcamwithalltheboys']
# Skipping invalid tweet with label 0: ['teatime']
# Skipping invalid tweet with label 0: ['indigo']
# Skipping invalid tweet with label 1: ['ftotheatothertothemtotheatothestothei', 'aminyaallah']
# Skipping invalid tweet with label 1: ['thatscute']
# Skipping invalid tweet with label 0: ['emotionally', 'raped']
# Skipping invalid tweet with label 1: ['greyjoggerswillalwayslookhotwhatevertheweather']
# Skipping invalid tweet with label 1: ['thesis', 'everydayplease']
# Skipping invalid tweet with label 0: ['tinychat']
# Skipping invalid tweet with label 0: ['justhateitwhenthestorerunsoutofpringleswithsourcreamandonionflavour']
# Skipping invalid tweet with label 1: ['millionkatycats']
# Skipping invalid tweet with label 0: ['yabebii']
# Skipping invalid tweet with label 0: []
# Skipping invalid tweet with label 1: ['felicisimofriday', 'whey']
# Skipping invalid tweet with label 1: ['yeahbaby']
# Skipping invalid tweet with label 1: ['dirtythoughts']
# Skipping invalid tweet with label 0: ['thingsimgoingtomisswhenigraduate', 'leahgallegerneedstwitter']
# Skipping invalid tweet with label 1: ['supershoutout_much_special']
# Skipping invalid tweet with label 1: ['senseofhumourfail', 'plssenddoughnuts']
# Skipping invalid tweet with label 1: ['thisgirll']
# Skipping invalid tweet with label 1: ['thnkyou']
# Skipping invalid tweet with label 1: ['willy', 'wonk']
# Skipping invalid tweet with label 0: ['byebilly']
# Skipping invalid tweet with label 0: ['iloveonedirectionandidontkonwwhyimtweetingaboutthiscuznobodywillreadthis']
# Skipping invalid tweet with label 0: ['pox']
# Skipping invalid tweet with label 1: ['everylittlethingisgonnabealright']
# Skipping invalid tweet with label 0: ['nee', 'nee', 'nee', 'nee', 'nee']
# Skipping invalid tweet with label 1: ['coughcough']
# Skipping invalid tweet with label 1: ['iknewicouldcountonyou']
# Skipping invalid tweet with label 0: ['stupidtwitter']
# Skipping invalid tweet with label 1: ['whateverydirectionerneedstoknow']
# Skipping invalid tweet with label 0: ['whatnot']
# Skipping invalid tweet with label 1: ['concerto']
# Skipping invalid tweet with label 1: ['psi']
# Skipping invalid tweet with label 1: ['whereas']
# Skipping invalid tweet with label 1: ['memmememememememe', 'followmeplease', 'xoxoxox']
# Skipping invalid tweet with label 0: ['nandobelly']
# Skipping invalid tweet with label 1: ['sexytimewithstyles']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['wonk', 'willy']
# Skipping invalid tweet with label 0: ['dame']
# Skipping invalid tweet with label 1: ['godmorning', 'tubby']
# Skipping invalid tweet with label 1: ['learningnewthings', 'takemenexttime', 'wishiwasthere']
# Skipping invalid tweet with label 1: ['buggy']
# Skipping invalid tweet with label 1: ['fatback']
# Skipping invalid tweet with label 1: ['hehehehe', 'shelly']
# Skipping invalid tweet with label 1: ['fridayfollow']
# Skipping invalid tweet with label 1: ['leigh']
# Skipping invalid tweet with label 0: ['chute']
# Skipping invalid tweet with label 0: ['luggage']
# Skipping invalid tweet with label 1: ['anytiimmee']
# Skipping invalid tweet with label 1: ['awebobrother']
# Skipping invalid tweet with label 1: ['thatsallthatsneeded']
# Skipping invalid tweet with label 1: ['ahahahahah', 'che', 'burton']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['goodmorningg']
# Skipping invalid tweet with label 1: ['liamdoatwitcamwithalltheboys']
# Skipping invalid tweet with label 1: ['bsbthanniversary']
# Skipping invalid tweet with label 1: ['jolly', 'rancher']
# Skipping invalid tweet with label 1: ['exelenthe']
# Skipping invalid tweet with label 1: ['freshly', 'shaved', 'callback']
# Skipping invalid tweet with label 0: ['godpleaseprotecthim']
# Skipping invalid tweet with label 1: ['longliveforthejonasbrothers']
# Skipping invalid tweet with label 0: ['imtheonewiththepenisthatneedsreducing']
# Skipping invalid tweet with label 0: ['comehomeplease']
# Skipping invalid tweet with label 1: ['withdabiebs']
# Skipping invalid tweet with label 1: ['raleigh', 'canary', 'campbell']
# Skipping invalid tweet with label 0: ['teamgrounded']
# Skipping invalid tweet with label 1: ['endyourdaywithasmile']
# Skipping invalid tweet with label 1: ['thankssaa', 'sue']
# Skipping invalid tweet with label 1: ['blatantly']
# Skipping invalid tweet with label 1: ['freeboosiethough']
# Skipping invalid tweet with label 1: ['heyfuturelightskinnedexhusband']
# Skipping invalid tweet with label 1: ['naturalhair']
# Skipping invalid tweet with label 1: ['teamalwayswinning']
# Skipping invalid tweet with label 1: ['deezythursday']
# Skipping invalid tweet with label 1: ['igotreallyboredsoidecidedtoinventthisreallylonghashtagthatsaysimboredandinventedthisbecauseimboredwelliloveyouemily']
# Skipping invalid tweet with label 0: ['skew']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['jataka']
# Skipping invalid tweet with label 1: ['racial']
# Skipping invalid tweet with label 1: ['nowfollowing']
# Skipping invalid tweet with label 1: ['followfriday']
# Skipping invalid tweet with label 1: ['mckay']
# Skipping invalid tweet with label 0: ['hahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahaha', 'awkwardlaugh']
# Skipping invalid tweet with label 1: ['uknowit']
# Skipping invalid tweet with label 1: ['nowfollowingback']
# Skipping invalid tweet with label 1: ['omgeezy']
# Skipping invalid tweet with label 1: ['okiedokie']
# Skipping invalid tweet with label 1: ['thatonewasforyous']
# Skipping invalid tweet with label 0: ['themomentyourealizeyouwillnevermeetonedirectionandyoustartcryingtheniallriver']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 1: ['thingsidoknow']
# Skipping invalid tweet with label 1: ['goethe']
# Skipping invalid tweet with label 1: ['movieandcuddletime_withbae']
# Skipping invalid tweet with label 1: ['shuttingdown', 'easyrock']
# Skipping invalid tweet with label 0: ['alaric', 'frown']
# Skipping invalid tweet with label 0: ['iwantafollowbackfrom']
# Skipping invalid tweet with label 1: ['clinching', 'jackpot']
# Skipping invalid tweet with label 1: ['fambamtime', 'brotherfromanother']
# Skipping invalid tweet with label 1: ['thewantedonthevoice']
# Skipping invalid tweet with label 1: ['salchichas']
# Skipping invalid tweet with label 1: ['potentially']
# Skipping invalid tweet with label 1: ['imalwaysonyourmindevenwhenyournotthinking']
# Skipping invalid tweet with label 1: ['nowfollowingback']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['awn']
# Skipping invalid tweet with label 0: ['cantstopcrying', 'ireallyneedyounow']
# Skipping invalid tweet with label 1: ['hehehehe']
# Skipping invalid tweet with label 1: ['rounder', 'methinks']
# Skipping invalid tweet with label 1: ['whey']
# Skipping invalid tweet with label 1: ['wikiisaby']
# Skipping invalid tweet with label 1: ['waserrp']
# Skipping invalid tweet with label 1: ['lesser']
# Skipping invalid tweet with label 1: ['followingback']
# Skipping invalid tweet with label 1: []
# Skipping invalid tweet with label 0: ['followbackmepleaseharry']
# Processed 2269875 labeled tweets.

# %% [markdown]
# These next cells are used to loas the data from the saved files (If all are saved), if the kernel crashes

# %%
# # Open the file and process line by line
# final_tweets = []
# with open("l_all_tweets.txt", "r", encoding="utf-8") as file:
#     for line in file:
#         # Evaluate each line as a Python tuple (safe only if you trust the file)
#         try:
#             record = eval(line.strip())  # Convert string to tuple
#             final_tweets.append(record)
#         except Exception as e:
#             print(f"Error parsing line: {line} - {e}")
# # Load the GloVe embedding matrix
# embedding_matrix_200 = np.load("embedding_matrix_glove_200.npy")
# # Load the vocabulary from the .pkl file
# with open("vocab.pkl", "rb") as file:
#     vocab = pickle.load(file)
# Out:
# (1, ['data', 'but', 'i', 'thought'])
# (1, ['i', 'did', 'at', 'first', 'but', 'she', 'is', 'going', 'on', 'me', '.', 'kim', 'is', 'my', 'far'])
# (0, ['awe', 'is', 'not', 'visible'])
# (0, ['so', 'my', 'mom', 'got', 'me', 'a', 'surprise', 'that', 'wa', '$', 'and', 'she', 'will', 'not', 'tell', 'me', 'what', 'it', 'is', 'bo'])
# (1, ['downplaying', '-', 'no', 'one', 'doe', 'it', 'better', '(', 'acoustic', ')', '-', 'you', 'me', 'at', 'six', 'heart'])

# %% [markdown]
# ### **Model Training**

# %%
# Split into train and test sets
test_size = 20000  # Adjust as needed
test_data = final_tweets[:test_size]  # First `test_size` entries for testing
train_data = final_tweets[test_size:]  # Remaining data for training

# %%
# Use the 200-dimensional embedding matrix
embedding_matrix = embedding_matrix_200


# Prepare training data
train_labels, train_tokenized_tweets = zip(*train_data)
X_train = get_batch_embeddings(train_tokenized_tweets, vocab, embedding_matrix)
y_train = np.array(train_labels)

# Normalize training data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
# Training parameters
alpha = 0.01  # Regularization parameter for SGD
max_iter = 10000
eta0 = 0.001
penalty = "l2"
loss = "hinge"
tol =1e-4

print("\nTraining and evaluating model with 200-dimensional embeddings...")

# Initialize and train classifier
clf = SGDClassifier(loss=loss, max_iter=max_iter, alpha=alpha, tol=tol ,penalty=penalty, learning_rate="constant", eta0=eta0)
print("Training model...")
clf.fit(X_train, y_train)  # Fit the model directly on the entire dataset
print("Training with 200-dimensional embeddings complete.")

# Prepare test data
test_labels, test_tokenized_tweets = zip(*test_data)
X_test = get_batch_embeddings(test_tokenized_tweets, vocab, embedding_matrix)
y_test = np.array(test_labels)

# Normalize test data
X_test = scaler.transform(X_test)

# Predict and evaluate
y_pred = clf.predict(X_test)
print("\nClassification Report for 200-dimensional embeddings:")
print(classification_report(y_test, y_pred))
# Out:
# Training and evaluating model with 200-dimensional embeddings...
# Training model...
# Training with 200-dimensional embeddings complete.
#
# Classification Report for 200-dimensional embeddings:
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75     10086
#            1       0.74      0.78      0.76      9914
#
#     accuracy                           0.76     20000
#    macro avg       0.76      0.76      0.76     20000
# weighted avg       0.76      0.76      0.76     20000

# %% [markdown]
# This next cell is for the crowd AI submission whuch yielded and accuracy of **0.77**

# %%
import numpy as np
import pandas as pd

# Prepare test data
print("\nPreparing test data for submission...")
X_submission = get_batch_embeddings(c3_test_tweets, vocab, embedding_matrix)

# Normalize test data using the same scaler used during training
X_submission = scaler.transform(X_submission)

# Predict test data (model generates 0 and 1)
print("Predicting submission data...")
y_submission = clf.predict(X_submission)

# Convert 0 to -1 in predictions
y_submission_adjusted = np.where(y_submission == 0, -1, y_submission)

# Save adjusted predictions to a file (submission.csv)
submission_filename = "submission.csv"
print(f"Saving adjusted predictions to {submission_filename}...")

# Create a DataFrame with Id starting at 1
submission_df = pd.DataFrame({
    "Id": range(1, len(y_submission_adjusted) + 1),  # IDs start at 1
    "Prediction": y_submission_adjusted
})

# Save to CSV
submission_df.to_csv(submission_filename, index=False)

print("Submission file created successfully with 'Id' starting at 1.")
# Out:
# Preparing test data for submission...
# Predicting submission data...
# Saving adjusted predictions to submission.csv...
# Submission file created successfully with 'Id' starting at 1.
